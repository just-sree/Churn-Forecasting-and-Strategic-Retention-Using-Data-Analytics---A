# %% [markdown]
# # Univariate Analysis

# %%
# notebooks/univariate_analysis.ipynb

# Run another notebook
# %run "D:/Personal Projects/Churn-Forecasting-and-Strategic-Retention-Using-Data-Analytics---A/notebooks/BIProject EDA.ipynb"

# Use the variables from the executed notebook
import sys
import os
import pandas as pd

# Add src directory to path
sys.path.append(os.path.abspath('../src'))

# Import the analysis function
from analysis.univariate import enhanced_telecom_analysis


# Run analysis with saving results
enhanced_telecom_analysis(churn_pred_df, "Churn Prediction Dataset", save_results=True)
enhanced_telecom_analysis(telco_churn_df, "Telco Customer Churn Dataset", save_results=True)

print("Analysis complete!")
# Out:
# Churn Prediction Dataset Description:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
# ...
